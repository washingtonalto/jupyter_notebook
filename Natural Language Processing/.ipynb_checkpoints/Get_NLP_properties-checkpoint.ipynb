# %%
import spacy
from spacy import displacy
# Out:
# 2023-02-20 11:03:07.589402: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def get_nlp_properties(txtInput):
    nlp = spacy.load('en_core_web_sm')
    doc = nlp(txtInput)
    print(f'Text input:\n{txtInput}\n')
    
    print(f'Token and lemma properties\n---------------')
    print(f"{'Token':{25}} {'token.pos_':{10}} {'token.lemma':<{22}} {'token.lemma_'}")
    print(f"{'-'*25:{25}} {'-'*10:{10}} {'-'*22:{22}} {'-'*30:{30}}")
    for token in doc:
        print(f'{token.text:{25}} {token.pos_:{10}} {token.lemma:<{22}} {token.lemma_}')
    print(f'---------------')
    
    print('\n')
    print(f'Sentence properties\n---------------')
    for sentence in doc.sents:
        print(sentence)
    print(f'---------------')

    print('\n')
    print(f'Entity properties\n---------------')
    print(f"{'Entity':{25}} {'entity.label_':{15}} {'entity label desc':{40}}")
    print(f"{'-'*25:{25}} {'-'*15:{15}} {'-'*40:{40}}")
    for entity in doc.ents:
        print(f'{str(entity):{25}} {str(entity.label_):{15}} {str(spacy.explain(entity.label_)):{40}}')
    print(f'---------------')

    spans = list(doc.sents)
    print('\n')
    print(f'Displacy entity properties\n---------------')
    displacy.render(spans,style="ent",jupyter=True,options={'distance':110,'compact':True})

    print('\n')
    print(f'Displacy entity properties\n---------------')
    displacy.render(spans,style="dep",jupyter=True,options={'distance':110,'compact':True})

    print('\n')
    print(f'Noun chunks properties\n---------------')
    for chunk in doc.noun_chunks:
        print(f'{chunk}')
    print(f'---------------')

    print('\n')
    print(f'Token and part of speech properties\n---------------')
    print(f"{'Token':{25}} {'token.pos_':{10}} {'token.tag_':{10}} {'token.tag_ desc'}")
    print(f"{'-'*25:{25}} {'-'*10:{10}} {'-'*10:{10}} {'-'*40:{40}}")
    for token in doc:
        print(f"{token.text:{25}} {token.pos_:{10}} {token.tag_:{10}} {spacy.explain(token.tag_)}")    
    print(f'---------------')

# %%
txtinput = u'Amazon itself uses AI to customize online retail offerings and recommend products to website visitors. The e-commerce behemoth also uses robotics and AI at its fulfillments centers. Further, Amazon leverages AI in retail stores, noted a recent Monness, Crespi, Hardt and Co. report to clients. More than 30 Amazon Fresh U.S. stores, over 25 Amazon Go U.S. stores and two Whole Foods Market stores use Just Walk Out payment technology.'

# %%
get_nlp_properties(txtinput)
# Out:
# Text input:
# Amazon itself uses AI to customize online retail offerings and recommend products to website visitors. The e-commerce behemoth also uses robotics and AI at its fulfillments centers. Further, Amazon leverages AI in retail stores, noted a recent Monness, Crespi, Hardt and Co. report to clients. More than 30 Amazon Fresh U.S. stores, over 25 Amazon Go U.S. stores and two Whole Foods Market stores use Just Walk Out payment technology.
#
# Token and lemma properties
# ---------------
# Token                     token.pos_ token.lemma            token.lemma_
# ------------------------- ---------- ---------------------- ------------------------------
# Amazon                    PROPN      7854762596996286480    Amazon
# itself                    PRON       12490679957485934169   itself
# uses                      VERB       6873750497785110593    use
# AI                        PROPN      5530044837203964789    AI
# to                        PART       3791531372978436496    to
# customize                 VERB       16306743478483088926   customize
# online                    ADJ        16939458712515879433   online
# retail                    ADJ        813965819887107378     retail
# offerings                 NOUN       5560822138508604498    offering
# and                       CCONJ      2283656566040971221    and
# recommend                 VERB       5869997465047222503    recommend
# products                  NOUN       2104994216896503478    product
# to                        PART       3791531372978436496    to
# website                   VERB       10703127324331283007   website
# visitors                  NOUN       5564268825592756684    visitor
# .                         PUNCT      12646065887601541794   .
# The                       DET        7425985699627899538    the
# e                         NOUN       1720370409040345145    e
# -                         NOUN       9153284864653046197    -
# commerce                  NOUN       2020969505356549135    commerce
# behemoth                  NOUN       7283229747530951081    behemoth
# also                      ADV        12084876542534825196   also
# uses                      VERB       6873750497785110593    use
# robotics                  NOUN       11193105105084215380   robotic
# and                       CCONJ      2283656566040971221    and
# AI                        PROPN      5530044837203964789    AI
# at                        ADP        11667289587015813222   at
# its                       PRON       12513610393978129441   its
# fulfillments              NOUN       5859727197696626148    fulfillment
# centers                   NOUN       14980700777765958138   center
# .                         PUNCT      12646065887601541794   .
# Further                   ADV        6785115870927179060    far
# ,                         PUNCT      2593208677638477497    ,
# Amazon                    PROPN      7854762596996286480    Amazon
# leverages                 VERB       6817220220335271795    leverage
# AI                        PROPN      5530044837203964789    AI
# in                        ADP        3002984154512732771    in
# retail                    ADJ        813965819887107378     retail
# stores                    NOUN       7338335557000497525    store
# ,                         PUNCT      2593208677638477497    ,
# noted                     VERB       5316588462688733335    note
# a                         DET        11901859001352538922   a
# recent                    ADJ        14101204033091332526   recent
# Monness                   PROPN      3967809660326683520    Monness
# ,                         PUNCT      2593208677638477497    ,
# Crespi                    PROPN      9184495928894380556    Crespi
# ,                         PUNCT      2593208677638477497    ,
# Hardt                     PROPN      8943192211981206896    Hardt
# and                       CCONJ      2283656566040971221    and
# Co.                       PROPN      5913782105554868606    Co.
# report                    NOUN       2729752284408055516    report
# to                        ADP        3791531372978436496    to
# clients                   NOUN       10852021146411011557   client
# .                         PUNCT      12646065887601541794   .
# More                      ADJ        16799767236440142622   More
# than                      ADP        10794458019344880855   than
# 30                        NUM        17750038938330149908   30
# Amazon                    PROPN      7854762596996286480    Amazon
# Fresh                     PROPN      12780552510584381201   Fresh
# U.S.                      PROPN      16611556673110956997   U.S.
# stores                    NOUN       7338335557000497525    store
# ,                         PUNCT      2593208677638477497    ,
# over                      ADP        5456543204961066030    over
# 25                        NUM        4522981160172931067    25
# Amazon                    PROPN      7854762596996286480    Amazon
# Go                        PROPN      5927671249132274586    Go
# U.S.                      PROPN      16611556673110956997   U.S.
# stores                    NOUN       7338335557000497525    store
# and                       CCONJ      2283656566040971221    and
# two                       NUM        11711838292424000352   two
# Whole                     PROPN      7165649864681787991    Whole
# Foods                     PROPN      4448342751415066844    Foods
# Market                    PROPN      12200839382758013798   Market
# stores                    NOUN       7338335557000497525    store
# use                       VERB       6873750497785110593    use
# Just                      ADV        7148522813498185515    just
# Walk                      VERB       1674876016505392235    walk
# Out                       ADP        1696981056005371314    out
# payment                   NOUN       103677957149620020     payment
# technology                NOUN       1740049878576065363    technology
# .                         PUNCT      12646065887601541794   .
# ---------------
#
#
# Sentence properties
# ---------------
# Amazon itself uses AI to customize online retail offerings and recommend products to website visitors.
# The e-commerce behemoth also uses robotics and AI at its fulfillments centers.
# Further, Amazon leverages AI in retail stores, noted a recent Monness, Crespi, Hardt and Co. report to clients.
# More than 30 Amazon Fresh U.S. stores, over 25 Amazon Go U.S. stores and two Whole Foods Market stores use Just Walk Out payment technology.
# ---------------
#
#
# Entity properties
# ---------------
# Entity                    entity.label_   entity label desc
# ------------------------- --------------- ----------------------------------------
# Amazon                    ORG             Companies, agencies, institutions, etc.
# AI                        ORG             Companies, agencies, institutions, etc.
# AI                        ORG             Companies, agencies, institutions, etc.
# Amazon                    ORG             Companies, agencies, institutions, etc.
# AI                        ORG             Companies, agencies, institutions, etc.
# Hardt and Co.             ORG             Companies, agencies, institutions, etc.
# More than 30              CARDINAL        Numerals that do not fall under another type
# Amazon Fresh              ORG             Companies, agencies, institutions, etc.
# U.S.                      GPE             Countries, cities, states
# 25                        CARDINAL        Numerals that do not fall under another type
# Amazon Go                 ORG             Companies, agencies, institutions, etc.
# U.S.                      GPE             Countries, cities, states
# two                       CARDINAL        Numerals that do not fall under another type
# Whole Foods Market        ORG             Companies, agencies, institutions, etc.
# ---------------
#
#
# Displacy entity properties
# ---------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  itself uses
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to customize online retail offerings and recommend products to website visitors. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The e-commerce behemoth also uses robotics and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  at its fulfillments centers. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Further,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  leverages
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in retail stores, noted a recent Monness, Crespi,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hardt and Co.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  report to clients. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     More than 30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon Fresh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  stores, over
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon Go
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  stores and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Whole Foods Market
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  stores use Just Walk Out payment technology.</div></span>
# Displacy entity properties
# ---------------
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="28b6fd6f4bf94c28b9aa52466d3d6646-0" class="displacy" width="1700" height="412.0" direction="ltr" style="max-width: none; height: 412.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Amazon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">itself</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">uses</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">AI</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">customize</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">online</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">retail</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">offerings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">recommend</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">products</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">website</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">visitors.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28b6fd6f4bf94c28b9aa52466d3d6646-0-0" stroke-width="2px" d="M62,277.0 62,240.33333333333334 261.0,240.33333333333334 261.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28b6fd6f4bf94c28b9aa52466d3d6646-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,279.0 L58,271.0 66,271.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28b6fd6f4bf94c28b9aa52466d3d6646-0-1" stroke-width="2px" d="M62,277.0 62,258.6666666666667 148.0,258.6666666666667 148.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28b6fd6f4bf94c28b9aa52466d3d6646-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M148.0,279.0 L152.0,271.0 144.0,271.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28b6fd6f4bf94c28b9aa52466d3d6646-0-2" stroke-width="2px" d="M282,277.0 282,258.6666666666667 368.0,258.6666666666667 368.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28b6fd6f4bf94c28b9aa52466d3d6646-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M368.0,279.0 L372.0,271.0 364.0,271.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28b6fd6f4bf94c28b9aa52466d3d6646-0-3" stroke-width="2px" d="M502,277.0 502,258.6666666666667 588.0,258.6666666666667 588.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28b6fd6f4bf94c28b9aa52466d3d6646-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M502,279.0 L498,271.0 506,271.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28b6fd6f4bf94c28b9aa52466d3d6646-0-4" stroke-width="2px" d="M282,277.0 282,240.33333333333334 591.0,240.33333333333334 591.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28b6fd6f4bf94c28b9aa52466d3d6646-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M591.0,279.0 L595.0,271.0 587.0,271.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28b6fd6f4bf94c28b9aa52466d3d6646-0-5" stroke-width="2px" d="M722,277.0 722,240.33333333333334 921.0,240.33333333333334 921.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28b6fd6f4bf94c28b9aa52466d3d6646-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M722,279.0 L718,271.0 726,271.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28b6fd6f4bf94c28b9aa52466d3d6646-0-6" stroke-width="2px" d="M832,277.0 832,258.6666666666667 918.0,258.6666666666667 918.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
# Noun chunks properties
# ---------------
# Amazon
# itself
# AI
# online retail offerings
# products
# visitors
# The e-commerce behemoth
# robotics
# AI
# its fulfillments centers
# Amazon
# AI
# retail stores
# a recent Monness, Crespi, Hardt and Co. report
# clients
# More than 30 Amazon Fresh U.S. stores
# over 25 Amazon Go U.S. stores
# two Whole Foods Market stores
# Just Walk Out payment technology
# ---------------
#
#
# Token and part of speech properties
# ---------------
# Token                     token.pos_ token.tag_ token.tag_ desc
# ------------------------- ---------- ---------- ----------------------------------------
# Amazon                    PROPN      NNP        noun, proper singular
# itself                    PRON       PRP        pronoun, personal
# uses                      VERB       VBZ        verb, 3rd person singular present
# AI                        PROPN      NNP        noun, proper singular
# to                        PART       TO         infinitival "to"
# customize                 VERB       VB         verb, base form
# online                    ADJ        JJ         adjective (English), other noun-modifier (Chinese)
# retail                    ADJ        JJ         adjective (English), other noun-modifier (Chinese)
# offerings                 NOUN       NNS        noun, plural
# and                       CCONJ      CC         conjunction, coordinating
# recommend                 VERB       VB         verb, base form
# products                  NOUN       NNS        noun, plural
# to                        PART       TO         infinitival "to"
# website                   VERB       VB         verb, base form
# visitors                  NOUN       NNS        noun, plural
# .                         PUNCT      .          punctuation mark, sentence closer
# The                       DET        DT         determiner
# e                         NOUN       NN         noun, singular or mass
# -                         NOUN       NN         noun, singular or mass
# commerce                  NOUN       NN         noun, singular or mass
# behemoth                  NOUN       NN         noun, singular or mass
# also                      ADV        RB         adverb
# uses                      VERB       VBZ        verb, 3rd person singular present
# robotics                  NOUN       NNS        noun, plural
# and                       CCONJ      CC         conjunction, coordinating
# AI                        PROPN      NNP        noun, proper singular
# at                        ADP        IN         conjunction, subordinating or preposition
# its                       PRON       PRP$       pronoun, possessive
# fulfillments              NOUN       NNS        noun, plural
# centers                   NOUN       NNS        noun, plural
# .                         PUNCT      .          punctuation mark, sentence closer
# Further                   ADV        RB         adverb
# ,                         PUNCT      ,          punctuation mark, comma
# Amazon                    PROPN      NNP        noun, proper singular
# leverages                 VERB       VBZ        verb, 3rd person singular present
# AI                        PROPN      NNP        noun, proper singular
# in                        ADP        IN         conjunction, subordinating or preposition
# retail                    ADJ        JJ         adjective (English), other noun-modifier (Chinese)
# stores                    NOUN       NNS        noun, plural
# ,                         PUNCT      ,          punctuation mark, comma
# noted                     VERB       VBD        verb, past tense
# a                         DET        DT         determiner
# recent                    ADJ        JJ         adjective (English), other noun-modifier (Chinese)
# Monness                   PROPN      NNP        noun, proper singular
# ,                         PUNCT      ,          punctuation mark, comma
# Crespi                    PROPN      NNP        noun, proper singular
# ,                         PUNCT      ,          punctuation mark, comma
# Hardt                     PROPN      NNP        noun, proper singular
# and                       CCONJ      CC         conjunction, coordinating
# Co.                       PROPN      NNP        noun, proper singular
# report                    NOUN       NN         noun, singular or mass
# to                        ADP        IN         conjunction, subordinating or preposition
# clients                   NOUN       NNS        noun, plural
# .                         PUNCT      .          punctuation mark, sentence closer
# More                      ADJ        JJR        adjective, comparative
# than                      ADP        IN         conjunction, subordinating or preposition
# 30                        NUM        CD         cardinal number
# Amazon                    PROPN      NNP        noun, proper singular
# Fresh                     PROPN      NNP        noun, proper singular
# U.S.                      PROPN      NNP        noun, proper singular
# stores                    NOUN       NNS        noun, plural
# ,                         PUNCT      ,          punctuation mark, comma
# over                      ADP        IN         conjunction, subordinating or preposition
# 25                        NUM        CD         cardinal number
# Amazon                    PROPN      NNP        noun, proper singular
# Go                        PROPN      NNP        noun, proper singular
# U.S.                      PROPN      NNP        noun, proper singular
# stores                    NOUN       NNS        noun, plural
# and                       CCONJ      CC         conjunction, coordinating
# two                       NUM        CD         cardinal number
# Whole                     PROPN      NNP        noun, proper singular
# Foods                     PROPN      NNPS       noun, proper plural
# Market                    PROPN      NNP        noun, proper singular
# stores                    NOUN       NNS        noun, plural
# use                       VERB       VBP        verb, non-3rd person singular present
# Just                      ADV        RB         adverb
# Walk                      VERB       VB         verb, base form
# Out                       ADP        RP         adverb, particle
# payment                   NOUN       NN         noun, singular or mass
# technology                NOUN       NN         noun, singular or mass
# .                         PUNCT      .          punctuation mark, sentence closer
# ---------------
